# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup


import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os


# Import API key
from api_keys import g_key
print(g_key)
# Out:
# AIzaSyDvlqBLINtFSxPxZK2A-HAetCLAazJzcAY

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
weather_data = pd.read_csv('wetherpycsv.csv')
weather_data
# Out:
#      Unnamed: 0            city  Lattitude   temp  Humidity  Cloudiness  \
# 0             0         bubaque      11.28  25.29        73          69
# 1             1      butaritari       3.07  28.86        79          97
# 2             2  port macquarie     -31.43  30.66        51          13
# 3             3         rikitea     -23.12  26.60        78          43
# 4             4            surt      31.21  10.98        85           0
# ..          ...             ...        ...    ...       ...         ...
# 544         544            abha      18.22  12.48        81          40
# 545         545      haileybury      47.45  -7.00        92          90
# 546         546           sabha      27.04  12.56        36          85
# 547         547   qasigiannguit      68.82 -14.00        60         100
# 548         548           wagar      16.15  17.48        69          33
#
#      WindSpeed  longitude
# 0         4.39     -15.83
# 1        10.28     172.79
# ...

# %%
weather_data12= weather_data.drop(columns="Unnamed: 0" )
weather_data12
# Out:
#                city  Lattitude   temp  Humidity  Cloudiness  WindSpeed  \
# 0           bubaque      11.28  25.29        73          69       4.39
# 1        butaritari       3.07  28.86        79          97      10.28
# 2    port macquarie     -31.43  30.66        51          13       6.70
# 3           rikitea     -23.12  26.60        78          43       2.34
# 4              surt      31.21  10.98        85           0       1.74
# ..              ...        ...    ...       ...         ...        ...
# 544            abha      18.22  12.48        81          40       3.60
# 545      haileybury      47.45  -7.00        92          90       5.70
# 546           sabha      27.04  12.56        36          85       4.62
# 547   qasigiannguit      68.82 -14.00        60         100       4.60
# 548           wagar      16.15  17.48        69          33       1.95
#
#      longitude
# 0       -15.83
# 1       172.79
# 2       152.92
# 3      -134.97
# 4        16.59
# ..         ...
# ...

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
gmaps.configure(api_key=g_key)


locations = weather_data12[["Lattitude", "longitude"]].astype(float)
Humidity = weather_data12["Humidity"].astype(float)





fig = gmaps.figure()




heat_layer = gmaps.heatmap_layer(locations, weights=Humidity, 
                                 dissipating=False, max_intensity=100,
                                 point_radius = 1)

fig.add_layer(heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
maxtemp = weather_data12[weather_data12.temp <= 29 ]
idealtemp = maxtemp[maxtemp.temp >= 15 ]
idawind= idealtemp[idealtemp.WindSpeed <= 10 ]
Idial =idawind[idawind.Cloudiness <=0]
Idial
# Out:
#                  city  Lattitude   temp  Humidity  Cloudiness  WindSpeed  \
# 18       saint-pierre     -21.34  26.11        57           0       5.10
# 57           luderitz     -26.65  16.00        63           0       2.60
# 62     guerrero negro      27.98  15.45        78           0       1.20
# 75         nouadhibou      20.93  16.00        72           0       7.20
# 84               chuy     -33.70  15.03        78           0       1.47
# 158         taoudenni      22.68  17.56        21           0       3.92
# 169          vallenar     -28.57  16.11        80           0       0.91
# 189            norton     -17.88  16.00        82           0       4.47
# 204         rangapara      26.82  17.21        48           0       2.19
# 212      constitucion     -35.33  15.59        80           0       3.36
# 238              doka      13.52  20.94        36           0       2.14
# 249  vega de alatorre      20.03  23.08        86           0       4.92
# ...

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
Idial["Hotel"] = ""
hotel=Idial
hotel
# Out:
# /Users/blakewilfong/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                  city  Lattitude   temp  Humidity  Cloudiness  WindSpeed  \
# 18       saint-pierre     -21.34  26.11        57           0       5.10
# 57           luderitz     -26.65  16.00        63           0       2.60
# 62     guerrero negro      27.98  15.45        78           0       1.20
# 75         nouadhibou      20.93  16.00        72           0       7.20
# 84               chuy     -33.70  15.03        78           0       1.47
# 158         taoudenni      22.68  17.56        21           0       3.92
# ...

# %%
params = {
    "radius": 50000,
    "types": "Hotel",
    "keyword": "Hotels",
    "key": g_key 
}



for index, row in Idial.iterrows():
    lat = row["Lattitude"]
    lng = row["longitude"]
    params["location"] = f"{lat},{lng}"
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    name_address = requests.get(base_url, params=params)
    name_address = name_address.json()
    try:
        hotel.loc[index, "Hotel"] = name_address["results"][0]["name"]
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
# Out:
# /Users/blakewilfong/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# Missing field/result... skipping.
# Missing field/result... skipping.

# %%
hotel
# Out:
#                  city  Lattitude   temp  Humidity  Cloudiness  WindSpeed  \
# 18       saint-pierre     -21.34  26.11        57           0       5.10
# 57           luderitz     -26.65  16.00        63           0       2.60
# 62     guerrero negro      27.98  15.45        78           0       1.20
# 75         nouadhibou      20.93  16.00        72           0       7.20
# 84               chuy     -33.70  15.03        78           0       1.47
# 158         taoudenni      22.68  17.56        21           0       3.92
# 169          vallenar     -28.57  16.11        80           0       0.91
# 189            norton     -17.88  16.00        82           0       4.47
# 204         rangapara      26.82  17.21        48           0       2.19
# 212      constitucion     -35.33  15.59        80           0       3.36
# 238              doka      13.52  20.94        36           0       2.14
# 249  vega de alatorre      20.03  23.08        86           0       4.92
# ...

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel}</dd>
<dt>City</dt><dd>{city}</dd>

</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel.iterrows()]
locations = hotel[["Lattitude", "longitude"]]

# %%
# Add marker layer ontop of heat map
markers = gmaps.marker_layer(locations,hotel_info)
    
fig.add_layer(markers)
fig

# Display Map
# Out:
# Figure(layout=FigureLayout(height='420px'))
